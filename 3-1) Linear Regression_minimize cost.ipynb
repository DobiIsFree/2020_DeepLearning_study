# %% [markdown]
# # Gradient descent algorithm
#
# - minimize cost function
# - used many minimization problems
# - for a given cost function, cost(W, b) it will find Wm b to minimize cost
# - applied to more general function: cost(w1, w2, ...)
#
# ### How it works?
# : find lowest piont?

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(t):
    return t*t

t1 = np.arange(-4, 5, 1)

plt.plot(t1, f(t1))

plt.show()

# %% [markdown]
# 경사를 따라 가장 낮은 지점으로 이동
#
#
# - start with initial guesses
#     - start at 0,0 (any other value)
#     - Keep changing W, b a little bit to try and reduce cost(W, b)
# - Each time change parameters, select gradient which redues cost(W, b) the most possible
# - Repeat
# - Do so until converge to a local minimum

# %% [markdown]
# ## matplotlib

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import matplotlib.pyplot as plt

X = [1, 2, 3]
Y = [1, 2, 3]

W = tf.placeholder(tf.float32)
hypothesis = X*W

cost = tf.reduce_mean(tf.square(hypothesis - Y))
sess = tf.Session()
sess.run(tf.global_variables_initializer())

W_val = []
cost_val = []
for i in range(-30, 50):
    feed_W = i * 0.1
    curr_cost, curr_W = sess.run([cost, W], feed_dict={W: feed_W})
    W_val.append(curr_W)
    cost_val.append(curr_cost)
    
plt.plot(W_val, cost_val)
plt.show()
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
